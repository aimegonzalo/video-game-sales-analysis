# %%
import pandas as pd

# %%
g_s_df = pd.read_csv('vgchartz_enriched.csv')

# %%
g_s_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 64016 entries, 0 to 64015
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   img                      64016 non-null  str
#  1   title                    64016 non-null  str
#  2   console                  64016 non-null  str
#  3   genre                    64016 non-null  str
#  4   publisher                64016 non-null  str
#  5   developer                63999 non-null  str
#  6   has_critic_score         64016 non-null  bool
#  7   critic_score             6678 non-null   float64
#  8   has_total_sales_record   64016 non-null  bool
#  9   total_sales              18922 non-null  float64
#  10  has_na_sales_record      64016 non-null  bool
#  11  na_sales                 12637 non-null  float64
#  12  has_jp_sales_record      64016 non-null  bool
#  13  jp_sales                 6726 non-null   float64
# ...

# %%
#changing some data types
g_s_df["release_date"] = pd.to_datetime(g_s_df["release_date"])

# %%
g_s_df["last_update"] = pd.to_datetime(g_s_df["last_update"])

# %%
g_s_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 64016 entries, 0 to 64015
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   img                      64016 non-null  str
#  1   title                    64016 non-null  str
#  2   console                  64016 non-null  str
#  3   genre                    64016 non-null  str
#  4   publisher                64016 non-null  str
#  5   developer                63999 non-null  str
#  6   has_critic_score         64016 non-null  bool
#  7   critic_score             6678 non-null   float64
#  8   has_total_sales_record   64016 non-null  bool
#  9   total_sales              18922 non-null  float64
#  10  has_na_sales_record      64016 non-null  bool
#  11  na_sales                 12637 non-null  float64
#  12  has_jp_sales_record      64016 non-null  bool
#  13  jp_sales                 6726 non-null   float64
# ...

# %%
#checking duplicateds records
g_s_df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 64011    False
# 64012    False
# 64013    False
# 64014    False
# 64015    False
# Length: 64016, dtype: bool

# %%
g_s_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#checking duplicated titles
g_s_df["title"].duplicated().sum()
# Out:
# np.int64(24218)

# %%
title_duplicates_mask = g_s_df["title"].duplicated(keep=False)

# %%
g_s_df[title_duplicates_mask]
# Out:
#                                                  img  \
# 0      /games/boxart/full_6510540AmericaFrontccc.jpg
# 1      /games/boxart/full_5563178AmericaFrontccc.jpg
# 2                        /games/boxart/827563ccc.jpg
# 3      /games/boxart/full_9218923AmericaFrontccc.jpg
# 4      /games/boxart/full_4990510AmericaFrontccc.jpg
# ...                                              ...
# 64009    /games/boxart/full_2129671JapanFrontccc.jpg
# 64010    /games/boxart/full_2294305JapanFrontccc.jpg
# 64011  /games/boxart/full_2779838AmericaFrontccc.jpg
# 64012  /games/boxart/full_8031506AmericaFrontccc.jpg
# 64013  /games/boxart/full_6553045AmericaFrontccc.jpg
#
#                              title console         genre  \
# 0               Grand Theft Auto V     PS3        Action
# 1               Grand Theft Auto V     PS4        Action
# 2      Grand Theft Auto: Vice City     PS2        Action
# 3               Grand Theft Auto V    X360        Action
# ...

# %%
g_s_df[title_duplicates_mask].sort_values("title")
# Out:
#                                                  img  \
# 47263  /games/boxart/full_6946124AmericaFrontccc.jpg
# 47264  /games/boxart/full_7569449AmericaFrontccc.jpg
# 47265  /games/boxart/full_9093834AmericaFrontccc.jpg
# 47268  /games/boxart/full_8870515AmericaFrontccc.jpg
# 47266  /games/boxart/full_9079529AmericaFrontccc.jpg
# ...                                              ...
# 15498  /games/boxart/full_1817338AmericaFrontccc.jpg
# 18330                      /games/boxart/default.jpg
# 7741   /games/boxart/full_2106119AmericaFrontccc.png
# 28955                      /games/boxart/default.jpg
# 28954                      /games/boxart/default.jpg
#
#                               title console      genre publisher  \
# 47263                  #DRIVE Rally     PS4     Racing   Unknown
# 47264                  #DRIVE Rally     PS5     Racing   Unknown
# 47265                  #DRIVE Rally    XOne     Racing   Unknown
# ...

# %%
title_console_duplicates_mask = g_s_df[["title", "console", "developer","publisher"]].duplicated(keep=False)

# %%
g_s_df[title_console_duplicates_mask].sort_values("title")
# Out:
#                                                  img  \
# 18885    /games/boxart/full_6533178JapanFrontccc.jpg
# 63793  /games/boxart/full_3273209AmericaFrontccc.jpg
# 63794  /games/boxart/full_8608130AmericaFrontccc.jpg
# 14271     /games/boxart/full_838274JapanFrontccc.jpg
# 13118    /games/boxart/full_6793274JapanFrontccc.jpg
# ...                                              ...
# 63266  /games/boxart/full_9636671AmericaFrontccc.jpg
# 2439     /games/boxart/full_2726763JapanFrontccc.jpg
# 2438     /games/boxart/full_4455632JapanFrontccc.jpg
# 43231    /games/boxart/full_8161397JapanFrontccc.jpg
# 43232                   /games/boxart/6510255ccc.jpg
#
#                                                    title console  \
# 18885                Aokana: Four Rhythm Across the Blue      NS
# 63793                Aokana: Four Rhythm Across the Blue     PSV
# 63794                Aokana: Four Rhythm Across the Blue      NS
# ...

# %%
#Although there are repeated title + console combinations, the associated records differ in other attributes (e.g. developer, publisher, image, sales or critic score). Therefore, these records were preserved pending further domain validation.

# %%
g_s_df.to_csv("vgchartz_cleaned.csv", index=False)
