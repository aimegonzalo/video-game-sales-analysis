# %%
import pandas as pd

# %%
g_s_df = pd.read_csv('vgchartz-2024.csv')

# %%
g_s_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 64016 entries, 0 to 64015
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   img           64016 non-null  str
#  1   title         64016 non-null  str
#  2   console       64016 non-null  str
#  3   genre         64016 non-null  str
#  4   publisher     64016 non-null  str
#  5   developer     63999 non-null  str
#  6   critic_score  6678 non-null   float64
#  7   total_sales   18922 non-null  float64
#  8   na_sales      12637 non-null  float64
#  9   jp_sales      6726 non-null   float64
#  10  pal_sales     12824 non-null  float64
#  11  other_sales   15128 non-null  float64
#  12  release_date  56965 non-null  str
#  13  last_update   17879 non-null  str
# dtypes: float64(6), str(8)
# memory usage: 6.8 MB

# %%
(g_s_df.isnull().sum() / len(g_s_df) * 100).sort_values(ascending=False)
# Out:
# critic_score    89.568233
# jp_sales        89.493252
# na_sales        80.259623
# pal_sales       79.967508
# other_sales     76.368408
# last_update     72.071045
# total_sales     70.441765
# release_date    11.014434
# developer        0.026556
# publisher        0.000000
# img              0.000000
# genre            0.000000
# console          0.000000
# title            0.000000
# dtype: float64

# %%
#lets check critic_score nulls values
g_s_df["critic_score"].value_counts(dropna=False)
# Out:
# critic_score
# NaN    57338
# 8.0      355
# 7.0      332
# 7.5      277
# 8.5      214
#        ...
# 2.1        2
# 1.4        1
# 1.3        1
# 1.2        1
# 1.8        1
# Name: count, Length: 90, dtype: int64

# %%
#Now lets add a new conditional column, if the game has a critical score record = true, otherwise False
g_s_df.insert(
    6,
    "has_critic_score",
    g_s_df["critic_score"].notna())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 g_s_df.insert(
#       2     6,
#       3     "has_critic_score",
#       4     g_s_df["critic_score"].notna())
#
# File ~\Desktop\gh_proyectos\Data\Video+Game+Sales\.venv\Lib\site-packages\pandas\core\frame.py:5633, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    5629                 "'self.flags.allows_duplicate_labels' is False."
#    5630             )
#    5631         if not allow_duplicates and column in self.columns:
#    5632             # Should this be a different kind of error??
# -> 5633             raise ValueError(f"cannot insert {column}, already exists")
#    5634         if not is_integer(loc):
#    5635             raise TypeError("loc must be int")
#    5636         # convert non stdlib ints to satisfy typing checks
#
# ...

# %%
g_s_df
# Out:
#                                                  img  \
# 0      /games/boxart/full_6510540AmericaFrontccc.jpg
# 1      /games/boxart/full_5563178AmericaFrontccc.jpg
# 2                        /games/boxart/827563ccc.jpg
# 3      /games/boxart/full_9218923AmericaFrontccc.jpg
# 4      /games/boxart/full_4990510AmericaFrontccc.jpg
# ...                                              ...
# 64011  /games/boxart/full_2779838AmericaFrontccc.jpg
# 64012  /games/boxart/full_8031506AmericaFrontccc.jpg
# 64013  /games/boxart/full_6553045AmericaFrontccc.jpg
# 64014    /games/boxart/full_6012940JapanFrontccc.png
# 64015                      /games/boxart/default.jpg
#
#                                   title console         genre  \
# 0                    Grand Theft Auto V     PS3        Action
# 1                    Grand Theft Auto V     PS4        Action
# 2           Grand Theft Auto: Vice City     PS2        Action
# 3                    Grand Theft Auto V    X360        Action
# ...

# %%
#Now lets check total sales nulls
g_s_df["total_sales"].value_counts(dropna=False)
# Out:
# total_sales
# NaN     45094
# 0.01     1366
# 0.00     1352
# 0.02     1228
# 0.03      941
#         ...
# 2.43        1
# 2.36        1
# 2.26        1
# 2.10        1
# 1.77        1
# Name: count, Length: 483, dtype: int64

# %%
#Now, lets compare total sales with regional sales
g_s_df[["na_sales", "jp_sales", "pal_sales", "other_sales"]].sum(axis=1)
# Out:
# 0        20.33
# 1        19.39
# 2        16.15
# 3        15.87
# 4        15.08
#          ...
# 64011     0.00
# 64012     0.00
# 64013     0.00
# 64014     0.00
# 64015     0.00
# Length: 64016, dtype: float64

# %%
g_s_df["total_sales"]
# Out:
# 0        20.32
# 1        19.39
# 2        16.15
# 3        15.86
# 4        15.09
#          ...
# 64011      NaN
# 64012      NaN
# 64013      NaN
# 64014      NaN
# 64015      NaN
# Name: total_sales, Length: 64016, dtype: float64

# %%
# Observation:
# The total_sales values closely match the sum of the regional sales. Minor differences are likely due to rounding. 
# This suggests that total_sales is derived from the regional sales values.

# %%
g_s_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 64016 entries, 0 to 64015
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   img               64016 non-null  str
#  1   title             64016 non-null  str
#  2   console           64016 non-null  str
#  3   genre             64016 non-null  str
#  4   publisher         64016 non-null  str
#  5   developer         63999 non-null  str
#  6   has_critic_score  64016 non-null  bool
#  7   critic_score      6678 non-null   float64
#  8   total_sales       18922 non-null  float64
#  9   na_sales          12637 non-null  float64
#  10  jp_sales          6726 non-null   float64
#  11  pal_sales         12824 non-null  float64
#  12  other_sales       15128 non-null  float64
#  13  release_date      56965 non-null  str
#  14  last_update       17879 non-null  str
# dtypes: bool(1), float64(6), str(8)
# memory usage: 6.9 MB

# %%
#Now We´ll create new conditional columns for sales records
#other_sales:
g_s_df.insert(
    12,
    "has_other_sales_record",
    g_s_df["other_sales"].notna())

# %%
#pal_sales
g_s_df.insert(
    11,
    "has_pal_sales_record",
    g_s_df["pal_sales"].notna())

# %%
#jp_sales
g_s_df.insert(
    10,
    "has_jp_sales_record",
    g_s_df["jp_sales"].notna())

# %%
#na_sales
g_s_df.insert(
    9,
    "has_na_sales_record",
    g_s_df["na_sales"].notna())

# %%
#total_sales
g_s_df.insert(
    8,
    "has_total_sales_record",
    g_s_df["total_sales"].notna())

# %%
#lets check our current dataframe
g_s_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 64016 entries, 0 to 64015
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   img                     64016 non-null  str
#  1   title                   64016 non-null  str
#  2   console                 64016 non-null  str
#  3   genre                   64016 non-null  str
#  4   publisher               64016 non-null  str
#  5   developer               63999 non-null  str
#  6   has_critic_score        64016 non-null  bool
#  7   critic_score            6678 non-null   float64
#  8   has_total_sales_record  64016 non-null  bool
#  9   total_sales             18922 non-null  float64
#  10  has_na_sales_record     64016 non-null  bool
#  11  na_sales                12637 non-null  float64
#  12  has_jp_sales_record     64016 non-null  bool
#  13  jp_sales                6726 non-null   float64
#  14  has_pal_sales_record    64016 non-null  bool
# ...

# %%
#lets create a new data fot those null cases on release_date and last_update
g_s_df.insert(
    18,
    "has_release_date_record",
    g_s_df["release_date"].notna())

# %%
g_s_df.insert(
    20,
    "has_last_update_record",
    g_s_df["last_update"].notna())

# %%
#Developer contains only 17 missing values (0.026%), which are not expected to significantly impact the analysis
